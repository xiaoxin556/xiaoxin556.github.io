# %% [markdown]
# # Project_2

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from IPython.display import HTML
import plotly.graph_objects as go
import plotly.io as pio

# %%
# Open both file and read the information
esg_data = pd.read_csv('SP 500 ESG Risk Ratings.csv') 
financial_data = pd.read_csv('financials.csv')

# %%
# Check the columns and see if the names of some colunms match
print("ESG Data Columns:", esg_data.columns.tolist())
print("Financial Data Columns:", financial_data.columns.tolist())
# Out:
# ESG Data Columns: ['Symbol', 'Name', 'Address', 'Sector', 'Industry', 'Full Time Employees', 'Description', 'Total ESG Risk score', 'Environment Risk Score', 'Governance Risk Score', 'Social Risk Score', 'Controversy Level', 'Controversy Score', 'ESG Risk Percentile', 'ESG Risk Level']
# Financial Data Columns: ['Symbol', 'Name', 'Sector', 'Price', 'Price/Earnings', 'Dividend Yield', 'Earnings/Share', '52 Week Low', '52 Week High', 'Market Cap', 'EBITDA', 'Price/Sales', 'Price/Book', 'SEC Filings']

# %%
# Merge ESG data with financial data using stock symbols as the key
merged_data = pd.merge(esg_data, financial_data, on='Symbol', how='inner')

# Select relevant columns and remove any rows with missing values
clean_data = merged_data[['Symbol', 'Total ESG Risk score', 'Earnings/Share']].dropna()

# Take a random sample of maximum 50 companies for visualization
sample_data = clean_data.sample(n=min(50, len(clean_data)), random_state=42)

# %%
# Calculate the correlation between these two data, just wanna see if they are related in trend
correlation = sample_data['Total ESG Risk score'].corr(sample_data['Earnings/Share'])
print(f"Correlation between Total ESG Risk Score and Earnings/Share: {correlation:.3f}")
# Out:
# Correlation between Total ESG Risk Score and Earnings/Share: -0.117

# %%
# Draw the graph of 'Total ESG Risk Score by Company'
fig1 = px.bar(
        sample_data,
        x='Symbol',
        y='Total ESG Risk score',
        title='Total ESG Risk Score by Company',
        color='Total ESG Risk score',
        color_continuous_scale='reds'
    )
fig1.update_layout(xaxis_tickangle=-45)

HTML(fig1.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-p+CD6OWuQleYdl5rFcX7AFZz/f30AT2awXuXgOshW9w=" crossorigin="anonymous"></script>                <div id="5073c857-99a9-423d-8721-7499dfba9a3c" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5073c857-99a9-423d-8721-7499dfba9a3c")) {                    Plotly.newPlot(                        "5073c857-99a9-423d-8721-7499dfba9a3c",                        [{"hovertemplate":"Symbol=%{x}\u003cbr\u003eTotal ESG Risk score=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"..."},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["MRO","ULTA","WM","BMY","TXT","GM","SLB","PCAR","MET","NUE","FMC","TJX","MTD","SCHW","NFLX","HPQ","EMN","FTV","ADM","PLD","WMB","AVB","SWKS","ECL","EMR","INCY","XOM","FIS","AME","ABBV","VTR","PNW","TRV","ARE","MDT","PNR","SYY","VZ","CCL","KLAC","EQR","HLT","UPS","CVS","PSX","AEP","O","ALL","YUM","MOS"],"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":" ...

# %%
# Draw the graph of 'Earnings per Share by Company'
fig2 = px.bar(
        sample_data,
        x='Symbol',
        y='Earnings/Share',
        title='Earnings per Share by Company',
        color='Earnings/Share',
        color_continuous_scale='greens'
    )
fig2.update_layout(xaxis_tickangle=-45)

HTML(fig2.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-p+CD6OWuQleYdl5rFcX7AFZz/f30AT2awXuXgOshW9w=" crossorigin="anonymous"></script>                <div id="6129dd60-5414-427c-a583-99cad2139147" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6129dd60-5414-427c-a583-99cad2139147")) {                    Plotly.newPlot(                        "6129dd60-5414-427c-a583-99cad2139147",                        [{"hovertemplate":"Symbol=%{x}\u003cbr\u003eEarnings\u002fShare=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"MzMzMzMzBcAUrkfhehQaQEjhehSuRwVAMzMzMzMzBUA9CtejcD3yPwAAAAAAABhASOF6FK5H8b8AAAAAAAATQClcj8L1KOQ\u002fZmZmZmZmEED2KFyPwvX4P65H4XoUrgtAexSuR+F6LEDD9Shcj8L5PwAAAAAAAPQ\u002f16NwPQrX9z89CtejcD0kQK5H4XoUrgNAXI\u002fC9ShcAUB7FK5H4XoIQD0K16NwPeK\u002fcT0K16NwGUCkcD0K16MVQI\u002fC9ShcjxBAzczMzMzMAkBI4XoUrkfhPxSuR+F6FP4\u002fhetRuB6F+z+F61G4HoUHQFK4HoXrUQpAw\u002fUoXI\u002fC\u002fT+amZmZmZkPQD0K16NwPR1AH4XrUbge+T8fhetRuB4HQArXo3A9Cg1ApHA9CtejAEBxPQrXo3AdQKRwPQrXowxAhetRuB6FF0AUrkfhehT6P83MzMzMzPA\u002fexSuR+F6FkCkcD0K16MTQFyPwvUo3CNA16NwPQrX8z\u002fsUbgehevxP7gehetRuBJASOF6FK5HEEAzMzMzMzPrPw=="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["MRO","ULTA","WM","BMY","TXT","GM","SLB","PCAR","MET","NUE","FMC","TJX","MTD","SCHW","NFLX","HPQ","EMN","FTV","ADM","PLD","WMB","AVB","SWKS","ECL","EMR","INCY","XOM","FIS","AME","ABBV","VTR","PNW","TRV","ARE","MDT","PNR","SYY","VZ","CCL","KLAC","EQR","HLT","UPS","CVS","PSX","AEP","O","ALL","YUM","MOS"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzBcAUrkfhehQaQEjhehSuRwVAMzMzMzMzBUA9CtejcD3yPwAAAAAAABhASOF6FK5H8b8AAAAAAAATQClcj8L1KOQ\u002fZmZmZmZmEED2KFyPwvX4P65H4XoUrgtAexSuR+F6LEDD9Shcj8L5PwAAAAAAAPQ\u002f16NwPQrX9z89CtejcD0kQK5H4XoUrgNAXI\u002fC9ShcAUB7FK5H4XoIQD0K16NwPeK\u002fcT0K16NwGUCkcD0K16MVQI\u002fC9ShcjxBAzczMzMzMAkBI4XoUrkfhPxSuR+F6FP4\u002fhetRuB6F+z+F61G4HoUHQFK4HoXrUQpAw\u002fUoXI\u002fC\u002fT+amZmZmZkPQD0K16NwPR1AH4XrUbge+T8fhetRuB4HQArXo3A9Cg1ApHA9CtejAEBxPQrXo3AdQKRwPQrXowxAhetRuB6FF0AUrkfhehT6P83MzMzMzPA\u002fexSuR+F6FkCkcD0K16MTQFyPwvUo3CNA16NwPQrX8z\u002fsUbgehevxP7gehetRuBJASOF6FK5HEEAzMzMzMzPrPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333 ...

# %%
# Draw the graph showing correlation
fig3 = px.scatter(
        sample_data,
        x='Total ESG Risk score',
        y='Earnings/Share',
        title=f'ESG Risk Score vs Earnings/Share (Correlation: {correlation:.3f})',
        labels={
            'Total ESG Risk score': 'Total ESG Risk Score',
            'Earnings/Share': 'Earnings Per Share (EPS)'
        }
    )

HTML(fig3.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-p+CD6OWuQleYdl5rFcX7AFZz/f30AT2awXuXgOshW9w=" crossorigin="anonymous"></script>                <div id="152faeaa-8466-41da-8c56-54763c355893" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("152faeaa-8466-41da-8c56-54763c355893")) {                    Plotly.newPlot(                        "152faeaa-8466-41da-8c56-54763c355893",                        [{"hovertemplate":"Total ESG Risk Score=%{x}\u003cbr\u003eEarnings Per Share (EPS)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzBcAUrkfhehQaQEjhehSuRwVAMzMzMzMzBUA9CtejcD3yPwAAAAAAABhASOF6FK5H8b8AAAAAAAATQClcj8L1KOQ\u002fZmZmZmZmEED2KFyPwvX4P65H4XoUrgtAexSuR+F6LEDD9Shcj8L5PwAAAAAAAPQ\u002f16NwPQrX9z89CtejcD0kQK5H4XoUrgNAXI\u002fC9ShcAUB7FK5H4XoIQD0K16NwPeK\u002fcT0K16NwGUCkcD0K16MVQI\u002fC9ShcjxBAzczMzMzMAkBI4XoUrkfhPxSuR+F6FP4\u002fhetRuB6F+z+F61G4HoUHQFK4HoXrUQpAw\u002fUoXI\u002fC\u002fT+amZmZmZkPQD0K16NwPR1AH4XrUbge+T8fhetRuB4HQArXo3A9Cg1ApHA9CtejAEBxPQrXo3AdQKRwPQrXowxAhetRuB6FF0AUrkfhehT6P83MzMzMzPA\u002fexSuR+F6FkCkcD0K16MTQFyPwvUo3CNA16NwPQrX8z\u002fsUbgehevxP7gehetRuBJASOF6FK5HEEAzMzMzMzPrPw=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar ...
